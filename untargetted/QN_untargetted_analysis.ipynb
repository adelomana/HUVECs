# %% [markdown]
# <a href="https://colab.research.google.com/github/adelomana/HUVECs/blob/main/QN_untargetted_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas, numpy
import sklearn, sklearn.preprocessing

import seaborn
seaborn.set_theme(style="whitegrid", font_scale=2)

import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 'font.family':'sans-serif', 'xtick.labelsize':20, 'ytick.labelsize':20, 'figure.figsize':(9, 6)})

# %% [markdown]
# # User-defined variables

# %%
data_file = '/content/drive/MyDrive/hi/research/huvec/data/untargetted/ROSA_ACID_NEG_UT_NOMISNORM_AllBatches_untransformed.xlsx'
original_data = pandas.read_excel(data_file)
original_data.head()
# Out:
#       Unnamed: 0  Number  ...   X996.84303  X996.86003000000005
# 0  EC_Rosa_1_659       4  ...  2278.023742          2335.314302
# 1  EC_Rosa_1_666       5  ...  3421.428464          3531.897024
# 2  EC_Rosa_1_668       3  ...  1758.452722          1738.477130
# 3  EC_Rosa_1_695      31  ...  2284.850823          2055.847626
# 4  EC_Rosa_1_711      32  ...  2517.026143          2493.479576
#
# [5 rows x 1236 columns]

# %% [markdown]
# # Normalize data by cell numbers

# %%
info = original_data.iloc[:, :6]
info.head()
# Out:
#       Unnamed: 0  Number Treatment  Batch  Cell  number  TIME
# 0  EC_Rosa_1_659       4       EGM      1      480000.0     0
# 1  EC_Rosa_1_666       5       EGM      1      480000.0     0
# 2  EC_Rosa_1_668       3       EGM      1      480000.0     0
# 3  EC_Rosa_1_695      31       EGM      2           NaN     0
# 4  EC_Rosa_1_711      32       EGM      2           NaN     0

# %%
intensities = original_data.iloc[:, 6:]
intensities.head()
# Out:
#     X59.01097  X61.017890000000001  ...   X996.84303  X996.86003000000005
# 0  287.490913           468.605181  ...  2278.023742          2335.314302
# 1  180.314261           538.342307  ...  3421.428464          3531.897024
# 2  284.725250           346.699905  ...  1758.452722          1738.477130
# 3  215.383340           632.252573  ...  2284.850823          2055.847626
# 4  308.400509           461.052002  ...  2517.026143          2493.479576
#
# [5 rows x 1230 columns]

# %%
intensities_by_cell = intensities.div(original_data['Cell  number']/1e6, axis=0)
intensities_by_cell.head()
# Out:
#     X59.01097  X61.017890000000001  ...   X996.84303  X996.86003000000005
# 0  598.939402           976.260794  ...  4745.882797          4865.238129
# 1  375.654710          1121.546473  ...  7127.975967          7358.118801
# 2  593.177604           722.291469  ...  3663.443171          3621.827354
# 3         NaN                  NaN  ...          NaN                  NaN
# 4         NaN                  NaN  ...          NaN                  NaN
#
# [5 rows x 1230 columns]

# %%
normalized_met_by_cell = pandas.concat([info, intensities_by_cell.reindex(info.index)], axis=1)
normalized_met_by_cell.head()
# Out:
#       Unnamed: 0  Number  ...   X996.84303  X996.86003000000005
# 0  EC_Rosa_1_659       4  ...  4745.882797          4865.238129
# 1  EC_Rosa_1_666       5  ...  7127.975967          7358.118801
# 2  EC_Rosa_1_668       3  ...  3663.443171          3621.827354
# 3  EC_Rosa_1_695      31  ...          NaN                  NaN
# 4  EC_Rosa_1_711      32  ...          NaN                  NaN
#
# [5 rows x 1236 columns]

# %%
# remove conditions for which cell numbers are not available
print('conditions before filtering {}'.format(normalized_met_by_cell.shape[0]))
finite_normalized_met_by_cell = normalized_met_by_cell[numpy.isfinite(normalized_met_by_cell['Cell  number']) == True]
print('conditions after filtering {}'.format(finite_normalized_met_by_cell.shape[0]))
# Out:
# conditions before filtering 130
# conditions after filtering 121

# %%
finite_normalized_met_by_cell.head()
# Out:
#        Unnamed: 0  Number  ...    X996.84303  X996.86003000000005
# 0   EC_Rosa_1_659       4  ...   4745.882797          4865.238129
# 1   EC_Rosa_1_666       5  ...   7127.975967          7358.118801
# 2   EC_Rosa_1_668       3  ...   3663.443171          3621.827354
# 9   EC_Rosa_1_787      85  ...  12270.745784         10790.108692
# 10  EC_Rosa_1_805      84  ...  10437.888669          9955.916753
#
# [5 rows x 1236 columns]

# %% [markdown]
# # Visualize metabolites raw values

# %%
peak_names = finite_normalized_met_by_cell.columns.to_list()[6:]
print(len(peak_names))
peak_names[:10]
# Out:
# 1230
# ['X59.01097',
#  'X61.017890000000001',
#  'X67.016220000000004',
#  'X74.021450000000002',
#  'X77.052040000000005',
#  'X77.052049999999994',
#  'X78.956580000000002',
#  'X78.956770000000006',
#  'X79.955420000000004',
#  'X80.962869999999995']

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=finite_normalized_met_by_cell[peak_names[:10]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='Intensity')
# Out:
# [Text(0, 0.5, 'Intensity')]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=finite_normalized_met_by_cell[peak_names[:100]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='Intensity')
# Out:
# [Text(0, 0.5, 'Intensity')]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=finite_normalized_met_by_cell[peak_names[:1000]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='Intensity')
# Out:
# [Text(0, 0.5, 'Intensity')]

# %% [markdown]
# # Bring intensities to log10 scale

# %%
info = finite_normalized_met_by_cell.iloc[:, :6]
data = finite_normalized_met_by_cell.iloc[:, 6:]
transformed = data.apply(numpy.log10)
log10_finite_normalize_met_by_cell = pandas.concat([info, transformed.reindex(info.index)], axis=1)
log10_finite_normalize_met_by_cell.head()
# Out:
#        Unnamed: 0  Number  ... X996.84303  X996.86003000000005
# 0   EC_Rosa_1_659       4  ...   3.676317             3.687104
# 1   EC_Rosa_1_666       5  ...   3.852966             3.866767
# 2   EC_Rosa_1_668       3  ...   3.563889             3.558928
# 9   EC_Rosa_1_787      85  ...   4.088871             4.033026
# 10  EC_Rosa_1_805      84  ...   4.018613             3.998081
#
# [5 rows x 1236 columns]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=log10_finite_normalize_met_by_cell[peak_names[:10]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='log10 Intensity')
# Out:
# [Text(0, 0.5, 'log10 Intensity')]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=log10_finite_normalize_met_by_cell[peak_names[:100]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='log10 Intensity')
# Out:
# [Text(0, 0.5, 'log10 Intensity')]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.boxplot(data=log10_finite_normalize_met_by_cell[peak_names[:1000]], palette='tab10')
g.set(xticklabels=[])
g.tick_params(bottom=False)
g.set(ylabel='log10 Intensity')
# Out:
# [Text(0, 0.5, 'log10 Intensity')]

# %% [markdown]
# # Explore batch effect

# %%
metabolite_peak = 'X147.02834999999999' 
metabolite_name = '2-hydroxy glutarate'
treatment = 10
timepoint =  4

# %%
sub = log10_finite_normalize_met_by_cell[(log10_finite_normalize_met_by_cell['Treatment'] == treatment) & (log10_finite_normalize_met_by_cell['TIME'] == timepoint)]
sub.head(20)
# Out:
#        Unnamed: 0  Number  ... X996.84303  X996.86003000000005
# 26  EC_Rosa_1_670      13  ...   3.590517             3.782912
# 27  EC_Rosa_1_674      12  ...   3.829845             3.851151
# 28  EC_Rosa_1_682      14  ...   4.065947             3.990642
# 29  EC_Rosa_1_700      41  ...   3.953450             3.956216
# 30  EC_Rosa_1_709      39  ...   3.865608             3.843691
# 31  EC_Rosa_1_727      40  ...   4.001144             3.990272
# 32  EC_Rosa_1_746      68  ...   4.199291             4.193725
# 33  EC_Rosa_1_771      67  ...   4.067722             3.690713
# 34  EC_Rosa_1_772      66  ...   4.129828             4.146761
# 35  EC_Rosa_1_788      94  ...   3.783695             3.708145
# 36  EC_Rosa_1_797      95  ...   3.975360             3.930043
# 37  EC_Rosa_1_800      93  ...   4.063939             4.008705
# 38  EC_Rosa_1_830     119  ...   3.667910             3.626434
# 39  EC_Rosa_1_832     117  ...   3.711094             3.651059
# 40  EC_Rosa_1_852     118  ...   3.616259             3.571976
#
# [15 rows x 1236 columns]

# %%
before_values = []
positions = []; dot_values = []
batches = range(1, 5+1)
for batch_number in batches:
  values = sub[sub['Batch'] == batch_number][metabolite_peak].values
  before_values.append(values)
# Out:
# [3.16614609 3.06427155 3.00691525]
# [3.68773778 3.84015732 3.50972743]
# [2.98141411 2.86368589 3.12768679]
# [2.98926888 2.87410333 2.65727936]
# [3.03588103 2.95941674 3.16096031]

# %%
df = pandas.DataFrame(numpy.array(before_values).transpose())
df.columns = ['Batch' + str(batch_number) for batch_number in batches]
df
# Out:
#      Batch1    Batch2    Batch3    Batch4    Batch5
# 0  3.166146  3.687738  2.981414  2.989269  3.035881
# 1  3.064272  3.840157  2.863686  2.874103  2.959417
# 2  3.006915  3.509727  3.127687  2.657279  3.160960

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
seaborn.boxplot(data=df)
g = seaborn.swarmplot(data=df, color='black', size=10)
g.set(ylabel='cell norm. log10 Intensity', title='2-HG | treat. = 5 uM | t = 4 h', ylim=[2.6, 3.9])
# Out:
# [(2.6, 3.9),
#  Text(0, 0.5, 'cell norm. log10 Intensity'),
#  Text(0.5, 1.0, '2-HG | treat. = 5 uM | t = 4 h')]

# %%
#
# define function for quantile normalization
#
def quantile_normalization(df):

  "Quantile normalization consists on sorting, averaging and re-ordering."
  "For more information: https://cmdlinetips.com/2020/06/computing-quantile-normalization-in-python/"
  
  # step 1/3: sorting sample values
  df_sorted = pandas.DataFrame(numpy.sort(df.values, axis=0), index=df.index, columns=df.columns)
  # step 2/3: averaging rank values across samples
  df_mean = df_sorted.mean(axis=1)
  df_mean.index = numpy.arange(1, len(df_mean) + 1)
  # step 3/3: re-ordering samples
  df.rank(method="min").astype(int)
  df_qn = df.rank(method="min").stack().astype(int).map(df_mean).unstack()

  ### extra steps, outside of quantile normalization
  
  # (1/2) use df_qn as reference to map original values, so they can be merged later
  target_means = df_qn.mean(axis=0)
  target_sds = df_qn.std(axis=0)

  original_means = df.mean(axis=0)
  original_sds = df.std(axis=0)
  df_scaled = df.subtract(original_means, axis=1).div(original_sds, axis=1)

  df_target = df_scaled.mul(target_sds, axis=1).add(target_means, axis=1)

  # (2/2) join values as one single column
  joined_values = df_target.values.flatten()

  ### case-specific convenience function to quantify batch shift
  bs = (df.mean(axis=0) - df_qn.mean(axis=0)) / df_qn.mean(axis=0)
  batch_shift = pandas.DataFrame(bs).transpose()

  return df_qn, df_target, joined_values, batch_shift

# %%
df_qn, df_target, joined_values, batch_shift = quantile_normalization(df)

# %%
batch_shift
# Out:
#      Batch1    Batch2    Batch3    Batch4    Batch5
# 0 -0.015727  0.176101 -0.043915 -0.092092 -0.024366

# %%
print(df_qn.mean(axis=0))
print(df_qn.std(axis=0))

print(df_target.mean(axis=0))
print(df_target.std(axis=0))
# Out:
# Batch1    3.12831
# Batch2    3.12831
# Batch3    3.12831
# Batch4    3.12831
# Batch5    3.12831
# dtype: float64
# Batch1    0.12872
# Batch2    0.12872
# Batch3    0.12872
# Batch4    0.12872
# Batch5    0.12872
# dtype: float64
# Batch1    3.12831
# Batch2    3.12831
# Batch3    3.12831
# Batch4    3.12831
# Batch5    3.12831
# dtype: float64
# Batch1    0.12872
# Batch2    0.12872
# Batch3    0.12872
# Batch4    0.12872
# Batch5    0.12872
# dtype: float64

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
seaborn.boxplot(data=df_qn)
g = seaborn.swarmplot(data=df_qn, color='black', size=10)
g.set(ylabel=' QN cell norm. log10 Intensity', title='2-HG | treat. = 5 uM | t = 4 h', ylim=[2.6, 3.9])
# Out:
# [(2.6, 3.9),
#  Text(0, 0.5, ' QN cell norm. log10 Intensity'),
#  Text(0.5, 1.0, '2-HG | treat. = 5 uM | t = 4 h')]

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
seaborn.boxplot(data=df_target)
g = seaborn.swarmplot(data=df_target, color='black', size=10)
g.set(ylabel='mapped cell norm. log10 Intensity', title='2-HG | treat. = 5 uM | t = 4 h', ylim=[2.6, 3.9])
# Out:
# [(2.6, 3.9),
#  Text(0, 0.5, 'mapped cell norm. log10 Intensity'),
#  Text(0.5, 1.0, '2-HG | treat. = 5 uM | t = 4 h')]

# %%
print(joined_values)
print(joined_values.shape)
# Out:
# [3.26722781 3.13494947 3.1190498  3.2421266  3.10780868 3.10462479
#  3.25358184 3.00447048 3.15418572 3.01107134 3.01307778 2.99639906
#  3.26141009 2.98861805 3.26605035]
# (15,)

# %% [markdown]
# Comparison to previous batch normalization

# %%
previous_file = '/content/drive/MyDrive/hi/research/huvec/data/untargetted/AllBatchdata_BatchNorm.xlsx'
previous_data = pandas.read_excel(previous_file)

previous_sub = previous_data[(previous_data['Treatment'] == treatment) & (previous_data['TIME'] == timepoint)]

before_values = []
positions = []; dot_values = []
batches = range(1, 5+1)
for batch_number in batches:
  values = previous_sub[previous_sub['Batch'] == batch_number][metabolite_peak].values
  before_values.append(values)

df = pandas.DataFrame(numpy.array(before_values).transpose())
df.columns = ['Batch' + str(batch_number) for batch_number in batches]

matplotlib.pyplot.figure(figsize=(9, 6))
seaborn.boxplot(data=df)
g = seaborn.swarmplot(data=df, color='black', size=10)
g.set(ylabel='prev. norm. values', title='2-HG | treat. = 5 uM | t = 4 h')
# Out:
# [Text(0, 0.5, 'prev. norm. values'),
#  Text(0.5, 1.0, '2-HG | treat. = 5 uM | t = 4 h')]

# %% [markdown]
# # Correct batch effect

# %%
# working variable should be log10_finite_normalize_met_by_cell
log10_finite_normalize_met_by_cell.head()
# Out:
#        Unnamed: 0  Number  ... X996.84303  X996.86003000000005
# 0   EC_Rosa_1_659       4  ...   3.676317             3.687104
# 1   EC_Rosa_1_666       5  ...   3.852966             3.866767
# 2   EC_Rosa_1_668       3  ...   3.563889             3.558928
# 9   EC_Rosa_1_787      85  ...   4.088871             4.033026
# 10  EC_Rosa_1_805      84  ...   4.018613             3.998081
#
# [5 rows x 1236 columns]

# %%
treatments = ['EGM', 1, 10, 100]
timepoints = [0, 4, 24]

conditions = [('EGM', 0), ('EGM', 4), ('EGM', 24)]
for treatment in treatments[1:]:
    for timepoint in timepoints[1:]:
        condition = (treatment, timepoint)
        conditions.append(condition)
print(conditions)
# Out:
# [('EGM', 0), ('EGM', 4), ('EGM', 24), (1, 4), (1, 24), (10, 4), (10, 24), (100, 4), (100, 24)]

# %%
all_columns = ['Treatment', 'Time', 'Replicate'] + peak_names
peaks_ic = pandas.DataFrame(columns=all_columns)
batch_shift_ic = pandas.DataFrame(columns=['Batch' + str(batch_number) for batch_number in batches])

for condition in conditions:
  treatment = condition[0]; timepoint = condition[1]
  container = {}
  for peak_name in peak_names:
    print('working with treatment {}, timepoint {} and peak_name {}'.format(treatment, timepoint, peak_name))

    # (1/2) retrieve specific data
    sub = log10_finite_normalize_met_by_cell[(log10_finite_normalize_met_by_cell['Treatment'] == treatment) & (log10_finite_normalize_met_by_cell['TIME'] == timepoint)]

    before_values = {}
    for batch_number in batches:
      values = sub[sub['Batch'] == batch_number][peak_name].values
      # impute an average value in case of two values (Batch 5)
      if len(values) == 2:
        print('imputation')
        values = numpy.insert(values, 0, numpy.mean(values))
      if len(values) > 0:
        before_values['Batch{}'.format(batch_number)] = values

    df = pandas.DataFrame(before_values)
    print('\t found {} replicates, {} batches, {} data points'.format(df.shape[0], df.shape[1], sub.shape[0]))

    # (2/2) quantile normalization
    df_qn, df_target, joined_values, batch_shift = quantile_normalization(df)

    # (3/3) store information as needed
    container[peak_name] = joined_values

    batch_shift_ic = pandas.concat([batch_shift_ic, batch_shift], axis=0)
  
  # final storage
  for i in range(len(joined_values)):
    local_container = {'Replicate':i, 'Treatment':treatment, 'Time':timepoint}
    for peak_name in container:
      local_container[peak_name] = container[peak_name][i]
    peaks_ic = peaks_ic.append(local_container, ignore_index=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X918.83290999999997
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X928.81326000000001
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X928.82665999999995
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X928.85361999999998
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X928.86716999999999
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X932.19215999999994
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X932.20804999999996
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X957.19478000000004
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X957.21433999999999
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X957.22663
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X962.81850999999995
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X962.83609000000001
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X962.85298
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X962.86944000000005
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X968.30682999999999
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X970.29764
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X970.31845999999996
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X970.33735000000001
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X972.28162999999995
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X986.81443999999999
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.20851000000005
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.78913999999997
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.80704000000003
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.82538
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.84303
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 10, timepoint 24 and peak_name X996.86003000000005
# imputation
# 	 found 3 replicates, 5 batches, 14 data points
# working with treatment 100, timepoint 4 and peak_name X59.01097
# 	 found 3 replicates, 5 batches, 15 data points
# working with treatment 100, timepoint 4 and peak_name X61.017890000000001
# 	 found 3 replicates, 5 batches, 15 data points
# working with treatment 100, timepoint 4 and peak_name X67.016220000000004
# 	 found 3 replicates, 5 batches, 15 data points
# working with treatment 100, timepoint 4 and peak_name X74.021450000000002
# 	 found 3 replicates, 5 batches, 15 data points
# working with treatment 100, timepoint 4 and peak_name
000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X860.84960999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X860.86506999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X860.88039000000003
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X861.55412000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X868.17564000000004
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X868.19429000000002
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X868.21249999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.50469999999996
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.52017999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.51959999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.53687000000002
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.53785000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.55157999999994
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.55363999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X883.57375000000002
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.51376000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.52925000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.54165999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.54786000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.55427999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X884.56338000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.52329999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.54012999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.55120999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.55715999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.56862999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X885.57101
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X886.53539000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X886.55880999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X886.57330999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X893.19449999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X893.21762000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X894.19538999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X894.21055000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X894.86288000000002
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X906.21198000000004
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X906.23701000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X918.79764999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X918.81568000000004
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X918.83290999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X928.81326000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X928.82665999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X928.85361999999998
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X928.86716999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X932.19215999999994
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X932.20804999999996
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X957.19478000000004
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X957.21433999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X957.22663
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X962.81850999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X962.83609000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X962.85298
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X962.86944000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X968.30682999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X970.29764
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X970.31845999999996
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X970.33735000000001
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X972.28162999999995
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X986.81443999999999
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.20851000000005
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.78913999999997
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.80704000000003
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.82538
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.84303
# 	 found 3 replicates, 4 batches, 12 data points
# working with treatment 100, timepoint 24 and peak_name X996.86003000000005
# 	 found 3 replicates, 4 batches, 12 data points

# %%
peaks_ic.head()
# Out:
#   Treatment Time Replicate  ...  X996.82538  X996.84303  X996.86003000000005
# 0       EGM    0         0  ...    3.947087    3.851484             3.835826
# 1       EGM    0         1  ...    3.949868    3.974549             3.937870
# 2       EGM    0         2  ...    3.891479    3.969419             3.952886
# 3       EGM    0         3  ...    3.886564    3.835708             3.864500
# 4       EGM    0         4  ...    3.810435    3.776425             3.752313
#
# [5 rows x 1233 columns]

# %%
peaks_ic.tail()
# Out:
#     Treatment Time Replicate  ...  X996.82538  X996.84303  X996.86003000000005
# 118       100   24         7  ...    3.313068    3.302228             3.266164
# 119       100   24         8  ...    3.315545    3.670722             3.566318
# 120       100   24         9  ...    3.631911    3.611437             3.536360
# 121       100   24        10  ...    3.635273    3.544705             3.554927
# 122       100   24        11  ...    3.619592    3.653982             3.547019
#
# [5 rows x 1233 columns]

# %%
batch_shift_ic.head()
print(batch_shift_ic.shape)
# Out:
# (11070, 5)

# %%
11070/len(peak_names)
# Out:
# 9.0

# %% [markdown]
# # Visualize batch shifts

# %%
matplotlib.pyplot.figure(figsize=(9, 6))
g = seaborn.kdeplot(data=batch_shift_ic, fill=True, palette="tab10", alpha=1/4, linewidth=1/2)
g.set(xlim=(-0.2, 0.2))
matplotlib.pyplot.axvline(x=0, lw=2, alpha=3/4, color='black', ls=':')

# %% [markdown]
# # Store data for downstream analysis

# %%
storing_file = '/content/drive/MyDrive/hi/research/huvec/results/untargeted/batch_normalized_cell_number_normalized_log10_intensities_untargeted_data.csv'
peaks_ic.to_csv(storing_file)
print(peaks_ic.shape)
peaks_ic.head()
# Out:
# (123, 1233)
#   Treatment Time Replicate  ...  X996.82538  X996.84303  X996.86003000000005
# 0       EGM    0         0  ...    3.947087    3.851484             3.835826
# 1       EGM    0         1  ...    3.949868    3.974549             3.937870
# 2       EGM    0         2  ...    3.891479    3.969419             3.952886
# 3       EGM    0         3  ...    3.886564    3.835708             3.864500
# 4       EGM    0         4  ...    3.810435    3.776425             3.752313
#
# [5 rows x 1233 columns]
