# %%
import pandas, numpy
import scipy, scipy.stats

import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 'font.family':'FreeSans', 'xtick.labelsize':20, 'ytick.labelsize':20})

# %% [markdown]
# # 0. user-defined variables

# %%
data_file ='/home/adrian/projects/HUVECs/data/csv/HUVEC_AllMeasurements_Summary_21.12.2020.Extracellular_compiled.csv'

# %% [markdown]
# # 1. read data

# %%
df = pandas.read_csv(data_file, header = 1)
df.head()
# Out:
#   Sample ID  Experiment  Treatment  Timepoint (h) Cell numbers  Na+  Cl-  \
# 0        NaN        NaN        NaN            NaN          NaN   mM   mM
# 1          1          2        0.0            0.0       480000  121  111
# 2          2          2        0.5            0.0       480000  120  110
# 3          3          2        5.0            0.0       480000  121  111
# 4          4          2       50.0            0.0       480000  120  112
#
#   Glucose Lactate         Glutamine  ... Aspartic ac MS Glutamin  \
# 0      uM      uM                uM  ...          uM          uM
# 1    5800     300  2061.07033855966  ...      100.16    1422.455
# 2    5900     400  13548.1023587988  ...      114.53     1576.49
# 3    5900     300   1379.5430799426  ...      104.79    1597.895
# 4    6200     700  1459.60347346998  ...      103.17     1624.73
#
#   MS Glutamic ac Ornithine    Lysine Citrulline Glycin NL XLeu/Ile/Hopro  \
# 0             uM        uM        uM         uM        uM             uM
# 1       1577.685     31.58   1509.19      3.705   633.275          842.7
# 2       1738.505    34.935  1673.355       4.86    737.03        929.685
# 3        1618.63    31.085   1770.46       4.49   746.875          926.1
# 4       1547.505     29.82   1858.57      4.695    691.83        871.235
#
#   Methylhistidin Phenylalanine
# 0             uM            uM
# 1          2.165         156.8
# 2           2.04        171.59
# 3          2.375       166.795
# 4           1.72       160.115
#
# [5 rows x 33 columns]

# %% [markdown]
# # 2. format data

# %% [markdown]
# ## 2.1. select appropriate columns

# %%
selected_columns = [0, 1, 2, 3, 4] + [7, 8]
df = df.iloc[:, selected_columns]
df
# Out:
#      Sample ID  Experiment  Treatment  Timepoint (h) Cell numbers Glucose  \
# 0           NaN        NaN        NaN            NaN          NaN      uM
# 1             1          2        0.0            0.0       480000    5800
# 2             2          2        0.5            0.0       480000    5900
# 3             3          2        5.0            0.0       480000    5900
# 4             4          2       50.0            0.0       480000    6200
# ..          ...        ...        ...            ...          ...     ...
# 168   100um-4.3      EC024       50.0            4.0      2100000    4400
# 169  100um-24.1      EC024       50.0           24.0      2100000    3200
# 170  100um-24.2      EC024       50.0           24.0      2100000    3300
# 171  100um-24.3      EC024       50.0           24.0      2100000    3400
# 172         NaN        NaN        NaN            NaN          NaN     NaN
#
#     Lactate
# 0        uM
# 1       300
# 2       400
# 3       300
# 4       700
# ..      ...
# 168    1300
# 169    4900
# 170    4600
# 171    4500
# 172     NaN
#
# [173 rows x 7 columns]

# %% [markdown]
# ## 2.1. select appropriate rows

# %%
df.drop([0], inplace=True)
df.drop(list(range(141, 171+1)), inplace=True)

# %%
wdf = df[df['Cell numbers'].str.isnumeric() == True]
wdf['Cell numbers'] = wdf['Cell numbers'].astype(float)
# Out:
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wdf['Glucose'][wdf['Glucose'] == '-'] = float('nan')
wdf['Lactate'][wdf['Lactate'] == '-'] = float('nan')
# Out:
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/adrian/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:1021: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
wdf['Glucose'] = wdf['Glucose'].astype(float)
wdf['Lactate'] = wdf['Lactate'].astype(float)

wdf['Treatment'] = wdf['Treatment'].astype(float)
wdf['Timepoint (h)'] = wdf['Timepoint (h)'].astype(float)
# Out:
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
pandas.set_option("display.max_rows", 200, "display.max_columns", 20)
print(wdf)
# Out:
#     Sample ID  Experiment  Treatment  Timepoint (h)  Cell numbers  Glucose  \
# 1            1          2        0.0            0.0      480000.0   5800.0
# 2            2          2        0.5            0.0      480000.0   5900.0
# 3            3          2        5.0            0.0      480000.0   5900.0
# 4            4          2       50.0            0.0      480000.0   6200.0
# 5            5          2        0.0            4.0      560000.0   4700.0
# 6            6          2        0.0            4.0      560000.0   4600.0
# 7            7          2        0.0            4.0      560000.0   4900.0
# 8            8          2        0.5            4.0      510000.0   4900.0
# 9            9          2        0.5            4.0      510000.0   4800.0
# 10          10          2        0.5            4.0      510000.0   4600.0
# 11          11          2        5.0            4.0      380000.0   5100.0
# 12          12          2        5.0            4.0      380000.0   5100.0
# 13          13          2        5.0            4.0      380000.0   4800.0
# 14          14          2       50.0            4.0      205000.0   5700.0
# 15          15          2       50.0            4.0      205000.0   5400.0
# 16          16          2       50.0            4.0      205000.0   5500.0
# 17          17          2        0.0           24.0      830000.0    700.0
# 18          18          2        0.0           24.0      830000.0    900.0
# 19          19          2        0.0           24.0      830000.0   1000.0
# 20          20          2        0.5           24.0      585000.0    600.0
# 21          21          2        0.5           24.0      585000.0    700.0
# 22          22          2        0.5           24.0      585000.0   1200.0
# 23          23          2        5.0           24.0      525000.0    600.0
# 24          24          2        5.0           24.0      525000.0    900.0
# 25          25          2        5.0           24.0      525000.0    600.0
# 26          26          2       50.0           24.0      390000.0   1500.0
# 27          27          2       50.0           24.0      390000.0   1000.0
# 28          28          2       50.0           24.0      390000.0   1200.0
# 33          33          3        0.0            4.0      255000.0   4800.0
# 34          34          3        0.0            4.0      255000.0   4500.0
# 35          35          3        0.0            4.0      255000.0   5100.0
# 36          36          3        0.5            4.0      275000.0   4800.0
# 37          37          3        0.5            4.0      275000.0   4600.0
# 38          38          3        0.5            4.0      275000.0      NaN
# 39          39          3        5.0            4.0      305000.0      NaN
# 40          40          3        5.0            4.0      305000.0      NaN
# 41          41          3        5.0            4.0      305000.0      NaN
# 42          42          3       50.0            4.0      485000.0      NaN
# 43          43          3       50.0            4.0      485000.0      NaN
# 44          44          3       50.0            4.0      485000.0      NaN
# 45          45          3        0.0           24.0      730000.0   1700.0
# 46          46          3        0.0           24.0      730000.0   1200.0
# 47          47          3        0.0           24.0      730000.0   1100.0
# 48          48          3        0.5           24.0      630000.0   1300.0
# 49          49          3        0.5           24.0      630000.0   1300.0
# 50          50          3        0.5           24.0      630000.0   1300.0
# 51          51          3        5.0           24.0      330000.0   1400.0
# 52          52          3        5.0           24.0      330000.0   1400.0
# 53          53          3        5.0           24.0      330000.0      NaN
# 54          54          3       50.0           24.0      400000.0   2000.0
# 55          55          3       50.0           24.0      400000.0   2700.0
# 56          56          3       50.0           24.0      400000.0   2500.0
# 61          61          5        0.0            4.0      320000.0   4600.0
# 131        131          7        0.0           24.0      550000.0   1600.0
# 132        132          7        0.5           24.0      215000.0   1600.0
# 133        133          7        0.5           24.0      215000.0   1900.0
# 134        134          7        0.5           24.0      215000.0   1600.0
# 135        135          7        5.0           24.0      457000.0   2000.0
# 136        136          7        5.0           24.0      457000.0   1700.0
# 137        137          7        5.0           24.0      457000.0   1700.0
# 138        138          7       50.0           24.0     1150000.0   1600.0
# 139        139          7       50.0           24.0     1150000.0   1900.0
# 140        140          7       50.0           24.0     1150000.0   2800.0
#
#      Lactate
# 1      300.0
# 2      400.0
# 3      300.0
# 4      700.0
# 5     2900.0
# 6     2600.0
# 7     3000.0
# 8     2800.0
# 9     2900.0
# 10    2600.0
# 11    2400.0
# 12    2300.0
# 13    3000.0
# 14    1200.0
# 15    2100.0
# 16    1800.0
# 17   10200.0
# 18    9900.0
# 19    9800.0
# 20   10500.0
# 21    9100.0
# 22    9700.0
# 23    9700.0
# 24   10400.0
# 25   10500.0
# 26    9100.0
# 27   10500.0
# 28    9700.0
# 33    2600.0
# 34    2700.0
# 35    3000.0
# 36    2800.0
# 37    2800.0
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45    9300.0
# 46    9600.0
# 47    9600.0
# 48    9600.0
# 49    9700.0
# 50    9900.0
# 51    9900.0
# 52    9300.0
# 53       NaN
# 54    8100.0
# 55    6900.0
# 56    6300.0
# 61    2300.0
# 62    2200.0
# 63    2300.0
# 64    2400.0
# 65    2100.0
# 66    2300.0
# 67    2300.0
# 68    2100.0
# 69    2300.0
# 70    1800.0
# 71    1900.0
# 72    2000.0
# 73    8400.0
# 74    8900.0
# 75    8900.0
# 76    9400.0
# 77    8700.0
# 78    9000.0
# 79    8900.0
# 80    7200.0
# 81    9100.0
# 82    8500.0
# 83    8700.0
# 84    8900.0
# 85     100.0
# 86     400.0
# 87     200.0
# 88     500.0
# 89    1400.0
# 90    1300.0
# 91     800.0
# 92    1600.0
# 93    1400.0
# 94    1500.0
# 95    1700.0
# 96    1600.0
# 97    1300.0
# 98    1100.0
# 99    1200.0
# 100   1100.0
# 101   6300.0
# 102   6000.0
# 103   6500.0
# 104   4400.0
# 105   6900.0
# 106   4500.0
# 107   5300.0
# 108   5700.0
# 109   5600.0
# 117   1700.0
# 118   1700.0
# 119   1600.0
# 120   1600.0
# 121   1600.0
# 122    600.0
# 123   2200.0
# 124   1600.0
# 125   1900.0
# 126   1600.0
# 127   2000.0
# 128   2100.0
# 129   6300.0
# 130   6600.0
# 131   6600.0
# 132   6600.0
# 133   7900.0
# 134   8400.0
# 135   6500.0
# 136   7200.0
# 137   6800.0
# 138   7100.0
# 139   6700.0
# 140   5700.0

# %% [markdown]
# # 3. analysis

# %%
unique_experiments = list(set(wdf['Experiment'].tolist()))
unique_experiments.sort()
unique_experiments
# Out:
# ['2', '3', '5', '6', '7']

# %%
quant = []
for time in [4, 24]:
    for treatment in [0, 0.5, 5, 50]:
        box = []
        for experiment in unique_experiments:
            
            if time == 4:
                time_reference = 0
            elif time == 24:
                time_reference = 4
            else:
                raise ValueError('unrecognized time value')
                
            ###
            ### cell numbers for both metabolites
            ###
                
            cn_current = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time) & (wdf['Experiment'] == experiment)]['Cell numbers'].astype(float).values
            cn_reference = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time_reference) & (wdf['Experiment'] == experiment)]['Cell numbers'].astype(float).values
            
            cnc = 1e6/cn_current
            cnr = 1e6/cn_reference
            
            ###
            ### glucose
            ###
            
            glucose_fvs = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time) & (wdf['Experiment'] == experiment)]['Glucose'].astype(float).values
            glucose_fvs_reference = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time_reference) & (wdf['Experiment'] == experiment)]['Glucose'].astype(float).values
            
            glu_current = glucose_fvs*cnc
            glu_reference = glucose_fvs_reference*cnr
            
            glu_consumption = numpy.nanmean(glu_current) - numpy.nanmean(glu_reference)
            
            ###
            ### lactate
            ###
            
            lactate_fvs = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time) & (wdf['Experiment'] == experiment)]['Lactate'].astype(float).values
            lactate_fvs_reference = wdf[(wdf['Treatment'] == treatment) & (wdf['Timepoint (h)'] == time_reference) & (wdf['Experiment'] == experiment)]['Lactate'].astype(float).values
            
            lac_current = lactate_fvs*cnc
            lac_reference = lactate_fvs_reference*cnr
            
            lac_secretion = numpy.nanmean(lac_current) - numpy.nanmean(lac_reference)
            
            ###
            ### ratio
            ###
            
            ratio = abs(lac_secretion/glu_consumption)
            box.append(ratio)
            
            ###
            ### checks
            ###
            
            print(time, treatment, experiment)
            print('glucose fvs', glucose_fvs)
            print('glucose fvs ref', glucose_fvs_reference)
            print('cn current and reference', cn_current, cn_reference)
            print('glu current and reference', glu_current, glu_reference)
            print('glu consumption', glu_consumption)
            
            print('lac fvs', lactate_fvs, lactate_fvs_reference)
            print('lac', lac_current, lac_reference)
            print('lac secretion', lac_secretion)
            print('ratio', ratio)
            print()
            
        print()
        print('***')
        print()
        
        ###
        ### building quant
        ###
        quant.append(box)
# Out:
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: RuntimeWarning: divide by zero encountered in double_scalars
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# 4 0 2
# glucose fvs [4700. 4600. 4900.]
# glucose fvs ref [5800.]
# cn current and reference [560000. 560000. 560000.] [480000.]
# glu current and reference [8392.85714286 8214.28571429 8750.        ] [12083.33333333]
# glu consumption -3630.9523809523816
# lac fvs [2900. 2600. 3000.] [300.]
# lac [5178.57142857 4642.85714286 5357.14285714] [625.]
# lac secretion 4434.52380952381
# ratio 1.221311475409836
#
# 4 0 3
# glucose fvs [4800. 4500. 5100.]
# glucose fvs ref []
# cn current and reference [255000. 255000. 255000.] []
# glu current and reference [18823.52941176 17647.05882353 20000.        ] []
# glu consumption nan
# lac fvs [2600. 2700. 3000.] []
# lac [10196.07843137 10588.23529412 11764.70588235] []
# lac secretion nan
# ratio nan
#
# 4 0 5
# glucose fvs [4600. 4500. 4800.]
# glucose fvs ref []
# cn current and reference [320000. 320000. 320000.] []
# glu current and reference [14375.  14062.5 15000. ] []
# glu consumption nan
# lac fvs [2300. 2200. 2300.] []
# lac [7187.5 6875.  7187.5] []
# lac secretion nan
# ratio nan
#
# 4 0 6
# glucose fvs [4200. 4000. 3000.]
# glucose fvs ref [4100.]
# cn current and reference [350000. 350000. 350000.] [270000.]
# glu current and reference [12000.         11428.57142857  8571.42857143] [15185.18518519]
# glu consumption -4518.51851851852
# lac fvs [1400. 1300.  800.] [100.]
# lac [4000.         3714.28571429 2285.71428571] [370.37037037]
# lac secretion 2962.962962962963
# ratio 0.6557377049180326
#
# 4 0 7
# glucose fvs [4500. 4300. 4600.]
# glucose fvs ref []
# cn current and reference [550000. 550000. 550000.] []
# glu current and reference [8181.81818182 7818.18181818 8363.63636364] []
# glu consumption nan
# lac fvs [1700. 1700. 1600.] []
# lac [3090.90909091 3090.90909091 2909.09090909] []
# lac secretion nan
# ratio nan
#
#
# ***
#
# 4 0.5 2
# glucose fvs [4900. 4800. 4600.]
# glucose fvs ref [5900.]
# cn current and reference [510000. 510000. 510000.] [480000.]
# glu current and reference [9607.84313725 9411.76470588 9019.60784314] [12291.66666667]
# glu consumption -2945.261437908497
# lac fvs [2800. 2900. 2600.] [400.]
# lac [5490.19607843 5686.2745098  5098.03921569] [833.33333333]
# lac secretion 4591.503267973856
# ratio 1.5589459084604713
#
# 4 0.5 3
# glucose fvs [4800. 4600.   nan]
# glucose fvs ref []
# cn current and reference [275000. 275000. 275000.] []
# glu current and reference [17454.54545455 16727.27272727            nan] []
# glu consumption nan
# lac fvs [2800. 2800.   nan] []
# lac [10181.81818182 10181.81818182            nan] []
# lac secretion nan
# ratio nan
#
# 4 0.5 5
# glucose fvs [4900. 4600. 4800.]
# glucose fvs ref []
# cn current and reference [460000. 460000. 460000.] []
# glu current and reference [10652.17391304 10000.         10434.7826087 ] []
# glu consumption nan
# lac fvs [2400. 2100. 2300.] []
# lac [5217.39130435 4565.2173913  5000.        ] []
# lac secretion nan
# ratio nan
#
# 4 0.5 6
# glucose fvs [5400. 3700. 4100.]
# glucose fvs ref [5000.]
# cn current and reference [182000. 182000. 182000.] [270000.]
# glu current and reference [29670.32967033 20329.67032967 22527.47252747] [18518.51851852]
# glu consumption 5657.30565730566
# lac fvs [1600. 1400. 1500.] [400.]
# lac [8791.20879121 7692.30769231 8241.75824176] [1481.48148148]
# lac secretion 6760.27676027676
# ratio 1.1949640287769778
#
# 4 0.5 7
# glucose fvs [4000. 4200. 4900.]
# glucose fvs ref []
# cn current and reference [570000. 570000. 570000.] []
# glu current and reference [7017.54385965 7368.42105263 8596.49122807] []
# glu consumption nan
# lac fvs [1600. 1600.  600.] []
# lac [2807.01754386 2807.01754386 1052.63157895] []
# lac secretion nan
# ratio nan
#
#
# ***
#
# 4 5 2
# glucose fvs [5100. 5100. 4800.]
# glucose fvs ref [5900.]
# cn current and reference [380000. 380000. 380000.] [480000.]
# glu current and reference [13421.05263158 13421.05263158 12631.57894737] [12291.66666667]
# glu consumption 866.2280701754389
# lac fvs [2400. 2300. 3000.] [300.]
# lac [6315.78947368 6052.63157895 7894.73684211] [625.]
# lac secretion 6129.385964912281
# ratio 7.075949367088606
#
# 4 5 3
# glucose fvs [nan nan nan]
# glucose fvs ref []
# cn current and reference [305000. 305000. 305000.] []
# glu current and reference [nan nan nan] []
# glu consumption nan
# lac fvs [nan nan nan] []
# lac [nan nan nan] []
# lac secretion nan
# ratio nan
#
# 4 5 5
# glucose fvs [4700. 4200. 4800.]
# glucose fvs ref []
# cn current and reference [250000. 250000. 250000.] []
# glu current and reference [18800. 16800. 19200.] []
# glu consumption nan
# lac fvs [2300. 2100. 2300.] []
# lac [9200. 8400. 9200.] []
# lac secretion nan
# ratio nan
#
# 4 5 6
# glucose fvs [5300. 4700. 4300.]
# glucose fvs ref [4200.]
# cn current and reference [374000. 374000. 374000.] [270000.]
# glu current and reference [14171.12299465 12566.84491979 11497.32620321] [15555.55555556]
# glu consumption -2810.4575163398695
# lac fvs [1700. 1600. 1300.] [200.]
# lac [4545.45454545 4278.07486631 3475.93582888] [740.74074074]
# lac secretion 3359.0810061398297
# ratio 1.1952078928823113
#
# 4 5 7
# glucose fvs [4800. 4500. 5000.]
# glucose fvs ref []
# cn current and reference [550000. 550000. 550000.] []
# glu current and reference [8727.27272727 8181.81818182 9090.90909091] []
# glu consumption nan
# lac fvs [2200. 1600. 1900.] []
# lac [4000.         2909.09090909 3454.54545455] []
# lac secretion nan
# ratio nan
#
#
# ***
#
# 4 50 2
# glucose fvs [5700. 5400. 5500.]
# glucose fvs ref [6200.]
# cn current and reference [205000. 205000. 205000.] [480000.]
# glu current and reference [27804.87804878 26341.46341463 26829.26829268] [12916.66666667]
# glu consumption 14075.20325203252
# lac fvs [1200. 2100. 1800.] [700.]
# lac [ 5853.65853659 10243.90243902  8780.48780488] [1458.33333333]
# lac secretion 6834.349593495936
# ratio 0.4855595667870037
#
# 4 50 3
# glucose fvs [nan nan nan]
# glucose fvs ref []
# cn current and reference [485000. 485000. 485000.] []
# glu current and reference [nan nan nan] []
# glu consumption nan
# lac fvs [nan nan nan] []
# lac [nan nan nan] []
# lac secretion nan
# ratio nan
#
# 4 50 5
# glucose fvs [4800. 5000. 4400.]
# glucose fvs ref []
# cn current and reference [220000. 220000. 220000.] []
# glu current and reference [21818.18181818 22727.27272727 20000.        ] []
# glu consumption nan
# lac fvs [1800. 1900. 2000.] []
# lac [8181.81818182 8636.36363636 9090.90909091] []
# lac secretion nan
# ratio nan
#
# 4 50 6
# glucose fvs [4500. 3900. 4100.]
# glucose fvs ref [4500.]
# cn current and reference [250000. 250000. 250000.] [270000.]
# glu current and reference [18000. 15600. 16400.] [16666.66666667]
# glu consumption 0.0
# lac fvs [1100. 1200. 1100.] [500.]
# lac [4400. 4800. 4400.] [1851.85185185]
# lac secretion 2681.481481481481
# ratio inf
#
# 4 50 7
# glucose fvs [4600. 4600. 4500.]
# glucose fvs ref []
# cn current and reference [660000. 660000. 660000.] []
# glu current and reference [6969.6969697  6969.6969697  6818.18181818] []
# glu consumption nan
# lac fvs [1600. 2000. 2100.] []
# lac [2424.24242424 3030.3030303  3181.81818182] []
# lac secretion nan
# ratio nan
#
#
# ***
#
# 24 0 2
# glucose fvs [ 700.  900. 1000.]
# glucose fvs ref [4700. 4600. 4900.]
# cn current and reference [830000. 830000. 830000.] [560000. 560000. 560000.]
# glu current and reference [ 843.37349398 1084.3373494  1204.81927711] [8392.85714286 8214.28571429 8750.        ]
# glu consumption -7408.204245553643
# lac fvs [10200.  9900.  9800.] [2900. 2600. 3000.]
# lac [12289.15662651 11927.71084337 11807.22891566] [5178.57142857 4642.85714286 5357.14285714]
# lac secretion 6948.508318990248
# ratio 0.9379477250726043
#
# 24 0 3
# glucose fvs [1700. 1200. 1100.]
# glucose fvs ref [4800. 4500. 5100.]
# lac [12354.31235431 13286.71328671 13053.61305361] [4545.45454545 4278.07486631 3475.93582888]
# lac secretion 8798.391151332327
# ratio 1.1670203091846014
#
# 24 5 7
# glucose fvs [2000. 1700. 1700.]
# glucose fvs ref [4800. 4500. 5000.]
# cn current and reference [457000. 457000. 457000.] [550000. 550000. 550000.]
# glu current and reference [4376.36761488 3719.91247265 3719.91247265] [8727.27272727 8181.81818182 9090.90909091]
# glu consumption -4727.935813274982
# lac fvs [6500. 7200. 6800.] [2200. 1600. 1900.]
# lac [14223.19474836 15754.92341357 14879.64989059] [4000.         2909.09090909 3454.54545455]
# lac secretion 11498.043896293348
# ratio 2.431937393060503
#
#
# ***
#
# 24 50 2
# glucose fvs [1500. 1000. 1200.]
# glucose fvs ref [5700. 5400. 5500.]
# cn current and reference [390000. 390000. 390000.] [205000. 205000. 205000.]
# glu current and reference [3846.15384615 2564.1025641  3076.92307692] [27804.87804878 26341.46341463 26829.26829268]
# glu consumption -23829.476756306023
# lac fvs [ 9100. 10500.  9700.] [1200. 2100. 1800.]
# lac [23333.33333333 26923.07692308 24871.79487179] [ 5853.65853659 10243.90243902  8780.48780488]
# lac secretion 16750.052115905775
# ratio 0.7029131309596711
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: RuntimeWarning: Mean of empty slice
# 24 50 3
# glucose fvs [2000. 2700. 2500.]
# glucose fvs ref [nan nan nan]
# cn current and reference [400000. 400000. 400000.] [485000. 485000. 485000.]
# glu current and reference [5000. 6750. 6250.] [nan nan nan]
# glu consumption nan
# lac fvs [8100. 6900. 6300.] [nan nan nan]
# lac [20250. 17250. 15750.] [nan nan nan]
# lac secretion nan
# ratio nan
#
# 24 50 5
# glucose fvs [1700. 1700. 1900.]
# glucose fvs ref [4800. 5000. 4400.]
# cn current and reference [840000. 840000. 840000.] [220000. 220000. 220000.]
# glu current and reference [2023.80952381 2023.80952381 2261.9047619 ] [21818.18181818 22727.27272727 20000.        ]
# glu consumption -19411.97691197691
# lac fvs [8500. 8700. 8900.] [1800. 1900. 2000.]
# lac [10119.04761905 10357.14285714 10595.23809524] [8181.81818182 8636.36363636 9090.90909091]
# lac secretion 1720.779220779219
# ratio 0.08864523322802444
#
# 24 50 6
# glucose fvs []
# glucose fvs ref [4500. 3900. 4100.]
# cn current and reference [] [250000. 250000. 250000.]
# glu current and reference [] [18000. 15600. 16400.]
# glu consumption nan
# lac fvs [] [1100. 1200. 1100.]
# lac [] [4400. 4800. 4400.]
# lac secretion nan
# ratio nan
#
# 24 50 7
# glucose fvs [1600. 1900. 2800.]
# glucose fvs ref [4600. 4600. 4500.]
# cn current and reference [1150000. 1150000. 1150000.] [660000. 660000. 660000.]
# glu current and reference [1391.30434783 1652.17391304 2434.7826087 ] [6969.6969697  6969.6969697  6818.18181818]
# glu consumption -5093.104962670181
# lac fvs [7100. 6700. 5700.] [1600. 2000. 2100.]
# lac [6173.91304348 5826.08695652 4956.52173913] [2424.24242424 3030.3030303  3181.81818182]
# lac secretion 2773.3860342556004
# ratio 0.544537380356989
#
#
# ***
# /home/adrian/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice

# %% [markdown]
#  # 4. plot

# %%
f = matplotlib.pyplot.figure()
ax = f.add_subplot(111)

###
### boxplots
####

filtered = []
for element in quant:
    new = []
    for sub in element:
        if numpy.isnan(sub) == False:
            if numpy.isinf(sub) == False:
                if sub < 3:
                    new.append(sub)
    filtered.append(new)
print(filtered)

bx = matplotlib.pyplot.boxplot(filtered, showcaps=False, medianprops=dict(linewidth=2, color='black'), boxprops=dict(linewidth=2, color='gray'), whiskerprops=dict(linewidth=2, color='gray'))

###
### scatter plots
###

the_colors = ['blue', 'green', 'pink', 'orange', 'red']

x=[]; y=[]; exp_colors=[]
for i in range(len(quant)):
    for j in range(len(quant[i])):
        
        if quant[i][j] < 3:
          
            shift = 0.25
            r=-shift/2 + shift*numpy.random.random()
            x.append(i+1+r)

            y.append(quant[i][j])

            exp_colors.append(the_colors[j])

matplotlib.pyplot.scatter(x, y, s=80, c=exp_colors, alpha=0.9, linewidths=0)

###
### statistics
###

for pos in [5, 6, 7]:
    print(filtered[4])
    print(filtered[pos])
    print()
    stat, pvalue = scipy.stats.mannwhitneyu(filtered[4], filtered[pos])
    if 0.01 < pvalue < 0.05:
        print(pos, 'significant', numpy.mean(filtered[4]), numpy.mean(filtered[pos]), pvalue)
        matplotlib.pyplot.text(pos/8.4, 0.85, '*', transform=ax.transAxes, horizontalalignment='center', verticalalignment='center', fontsize=40)
    if pvalue < 0.01:
        print(pos, 'very significant', numpy.mean(filtered[5]), numpy.mean(filtered[pos]), pvalue)
        matplotlib.pyplot.text(pos/8.4, 0.85, '**', transform=ax.transAxes, horizontalalignment='center', verticalalignment='center', fontsize=40)

###
### close figure
###

matplotlib.pyplot.text(0.20, 0.9, 'T=4', transform=ax.transAxes, horizontalalignment='center', verticalalignment='center')
matplotlib.pyplot.text(0.75, 0.9, 'T=24', transform=ax.transAxes, horizontalalignment='center', verticalalignment='center')
    
matplotlib.pyplot.axvline(4.5, alpha=0.5, lw=2, color='black', ls=':')

matplotlib.pyplot.grid(alpha=1/3)

matplotlib.pyplot.xlabel('Treatment (uM)')
matplotlib.pyplot.ylabel('Lac/Glu ratio')
matplotlib.pyplot.xticks([1, 2, 3, 4, 5, 6, 7, 8], ['0', '0.5', '5', '50', '0', '0.5', '5', '50'])
matplotlib.pyplot.title('Lac/Glu')
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
# Out:
# [[1.221311475409836, 0.6557377049180326], [1.5589459084604713, 1.1949640287769778], [1.1952078928823113], [0.4855595667870037], [0.9379477250726043, 0.12731774125579434, 0.5263577214181385, 1.686046511627907], [1.4226782314364286, 0.35055374175788995, 0.8421172973590945, 0.026065014101232072], [1.071852479864349, 0.0374733327149615, 1.1670203091846014, 2.431937393060503], [0.7029131309596711, 0.08864523322802444, 0.544537380356989]]
# [0.9379477250726043, 0.12731774125579434, 0.5263577214181385, 1.686046511627907]
# [1.4226782314364286, 0.35055374175788995, 0.8421172973590945, 0.026065014101232072]
#
# [0.9379477250726043, 0.12731774125579434, 0.5263577214181385, 1.686046511627907]
# [1.071852479864349, 0.0374733327149615, 1.1670203091846014, 2.431937393060503]
#
# [0.9379477250726043, 0.12731774125579434, 0.5263577214181385, 1.686046511627907]
# [0.7029131309596711, 0.08864523322802444, 0.544537380356989]
